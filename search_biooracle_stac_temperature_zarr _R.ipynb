# %% [markdown]
# # Search BioOracle STAC Catalog for Temperature Zarr Assets
# This script searches a static STAC catalog for temperature data and retrieves Zarr assets.

# %%
library(httr)
library(jsonlite)
library(glue)
library(dplyr)
library(lubridate)
library(tidyr)

# %% [markdown]
# Here is the endpoint of the static STAC catalog.  It is a JSON file structure that contains links to other internal catalogs and collections.
# Be sure to read the STAC documentation to understand STAC specifications.
# https://github.com/radiantearth/stac-spec/tree/master

# %%
stac_endpoint_url <- "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/catalog.json"
# Extract the root by removing 'catalog.json'
stac_root <- dirname(stac_endpoint_url)

# %% [markdown]
# Retrieve the JSON data from the STAC endpoint.

# %%
response <- GET(stac_endpoint_url)
json_data <- fromJSON(content(response, as = "text", encoding = "UTF-8"))

# %% [markdown]
# Here we filter the links based on the keyword 'temperature' in the title. Since this STAC makes use of internal catalogs, we will need to loop through the catalogs to find the collections and items.

# %%
catalog_selector = 'temperature'
selected_catalogs <- json_data$links[grep(catalog_selector, json_data$links, ignore.case = TRUE), ]
selected_catalogs_titles <- json_data$links[grep(catalog_selector, json_data$links$title, ignore.case = TRUE), ]
print(selected_catalogs_titles$title)

catalog_links = glue('{stac_root}/{selected_catalogs_titles$title}/catalog.json')

print(catalog_links)
# Out:
# [1] "airtemperature"   "oceantemperature"
# https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/airtemperature/catalog.json
# https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/catalog.json

# %% [markdown]
# Loop through and print each catalog link.

# %%
for (i in seq_along(catalog_links)) {
  print(catalog_links[i])
}
# Out:
# https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/airtemperature/catalog.json
# https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/catalog.json

# %% [markdown]
# Loop through and get each collection from the 'oceantemperature' catalog, then get all the items in the 'thetao_mean' collection.

# %%
for (i in seq_along(catalog_links)) {
  print(catalog_links[i])
  internal_catalog_response = GET(catalog_links[i])
  internal_catalog_json <- fromJSON(content(internal_catalog_response, as = "text", encoding = "UTF-8"))
  print(internal_catalog_json)
}
# Out:
# https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/airtemperature/catalog.json
# $type
# [1] "Catalog"
#
# $id
# [1] "airtemperature"
#
# $stac_version
# [1] "1.0.0"
#
# $description
# [1] "Variable Family airtemperature"
#
# $links
#      rel                                                href             type
# 1   root                                     ../catalog.json application/json
# 2  child ./emodnet-bio_oracle_airtemperature/collection.json application/json
# 3 parent                                     ../catalog.json application/json
#                       title
# 1                Bio-Oracle
# 2 Bio-Oracle AirTemperature
# 3                Bio-Oracle
#
# $title
# [1] "airtemperature"
#
# https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/catalog.json
# $type
# [1] "Catalog"
#
# $id
# [1] "oceantemperature"
#
# $stac_version
# [1] "1.0.0"
#
# $description
# [1] "Variable Family oceantemperature"
#
# $links
#      rel                                                  href             type
# 1   root                                       ../catalog.json application/json
# 2  child ./emodnet-bio_oracle_oceantemperature/collection.json application/json
# 3  child                 ./emodnet-thetao_mean/collection.json application/json
# 4 parent                                       ../catalog.json application/json
#                         title
# 1                  Bio-Oracle
# 2 Bio-Oracle OceanTemperature
# 3                 thetao_mean
# 4                  Bio-Oracle
#
# $title
# [1] "oceantemperature"

# %% [markdown]
# Here is a function to get the links to the collections from the oceantemperature 'internal' catalog that is inside this STAC catalog.

# %%
get_catalog_links <- function(catalog_links) {
  selected_collections <- list()
  for (i in seq_along(catalog_links)) {
    if (grepl('oceantemperature', catalog_links[i], ignore.case = TRUE)) {
      cat_link <- catalog_links[i]
      cat_response <- GET(cat_link)
      cat_json <- fromJSON(content(cat_response, as = "text", encoding = "UTF-8"))
      links <- cat_json$links$href
      for (j in seq_along(links)) {
        if (grepl('collection.json', links[j], ignore.case = TRUE)) {
          collection <- gsub("^\\./", "", dirname(links[j]))
          selected_collections <- append(selected_collections, collection)
          print(collection)
        }
      }
    }
  }
  selected_collections
}

# %% [markdown]
# This function will get the STAC items inside the collections that contain 'thetao_mean' in their ID. These STAC items contain the actual data that we are interested in.

# %%
get_collection_items <- function(selected_collections, catalog_links) {
  selected_collection_items <- data.frame(item_link = character(), stringsAsFactors = FALSE)
  for (collection in selected_collections) {
    if (grepl('thetao_mean', collection, ignore.case = TRUE)) {
      cat_link <- catalog_links[grepl('oceantemperature', catalog_links, ignore.case = TRUE)][1]
      collection_link <- glue('{dirname(cat_link)}/{collection}/collection.json')
      collection_json <- fromJSON(content(GET(collection_link), as = 'text', encoding = 'UTF-8'))
      collection_links <- collection_json$links
      matched_rows <- collection_links[grepl('item', collection_links$rel, ignore.case = TRUE), ]
      if (nrow(matched_rows) > 0) {
        for (k in seq_len(nrow(matched_rows))) {
          item_href <- matched_rows[k, "href"]
          item_title <- matched_rows[k, 'title']
          item_href <- gsub("^\\./", "", item_href)
          item_link <- glue("{dirname(collection_link)}/{item_href}")
          item_link <- as.character(item_link)
          print(item_link)
          selected_collection_items <- rbind(selected_collection_items, data.frame(item_link = item_link, stringsAsFactors = FALSE))
        }
      } else {
        print(glue("No matches found for item: {item}"))
      }
    }
  }
  selected_collection_items
}

# %% [markdown]
# Here we execute the functions to get the links to the collections and the items inside the collections.

# %%
selected_collections <- get_catalog_links(catalog_links)
selected_collection_items <- get_collection_items(selected_collections, catalog_links)
print(selected_collection_items)
# Out:
# [1] "emodnet-bio_oracle_oceantemperature"
# [1] "emodnet-thetao_mean"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_baseline_-179.975_-89.975_179.975_89.975_2000-01-01 00:00:00+00:00_2010-01-01 00:00:00+00:00/thetao_mean__depthSurf_baseline_-179.975_-89.975_179.975_89.975_2000-01-01 00:00:00+00:00_2010-01-01 00:00:00+00:00.json"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp119_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp119_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp126_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp126_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp245_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp245_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp370_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp370_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp460_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp460_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json"
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp585_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp585_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json"
#                                                                                                                                                                                                                                                                                                                                    item_link
# 1 https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_baseline_-179.975_-89.975_179.975_89.975_2000-01-01 00:00:00+00:00_2010-01-01 00:00:00+00:00/thetao_mean__depthSurf_baseline_-179.975_-89.975_179.975_89.975_2000-01-01 00:00:00+00:00_2010-01-01 00:00:00+00:00.json
# 2     https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp119_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp119_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json
# 3     https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp126_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp126_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json
# 4     https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp245_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp245_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json
# 5     https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp370_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp370_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json
# 6     https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp460_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp460_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json
# 7     https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/stac/oceantemperature/emodnet-thetao_mean/thetao_mean__depthSurf_ssp585_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00/thetao_mean__depthSurf_ssp585_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00.json

# %% [markdown]
# This function fetches the JSON data for each item in the selected collection items DataFrame.

# %%
fetch_item_jsons <- function(selected_items_df) {
  item_jsons <- list()
  for (item_link in selected_items_df$item_link) {
    item_link <- URLencode(item_link)
    item_response <- GET(item_link)
    item_json <- fromJSON(content(item_response, as = 'text', encoding = 'UTF-8'))
    item_jsons <- append(item_jsons, list(item_json))
  }
  item_jsons
}

# %% [markdown]
# Finally, we fetch and display the JSONs for the selected items.

# %%
item_jsons <- fetch_item_jsons(selected_collection_items)
print(item_jsons)
# Out:
# [[1]]
# [[1]]$type
# [1] "Feature"
#
# [[1]]$stac_version
# [1] "1.0.0"
#
# [[1]]$id
# [1] "thetao_mean__depthSurf_baseline_-179.975_-89.975_179.975_89.975_2000-01-01 00:00:00+00:00_2010-01-01 00:00:00+00:00"
#
# [[1]]$properties
# [[1]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[1]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[1]]$properties$`proj:epsg`
# [1] 4326
#
# [[1]]$properties$start_datetime
# [1] "2000-01-01T00:00:00Z"
#
# [[1]]$properties$end_datetime
# [1] "2010-01-01T00:00:00Z"
#
# [[1]]$properties$native_variable
# [1] "thetao_mean"
#
# [[1]]$properties$datetime
# NULL
#
#
# [[1]]$geometry
# [[1]]$geometry$type
# [1] "Polygon"
#
# [[1]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[1]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[1]]$assets
# [[1]]$assets$NetCDF
# [[1]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_baseline_2000_2019_depthsurf/climatologydecadedepthsurf.nc"
#
# [[1]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[1]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[1]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[1]]$assets$Zarr
# [[1]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13813/climatologydecadedepthsurf.zarr"
#
# [[1]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[1]]$assets$Zarr$title
# [1] "Zarr"
#
# [[1]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[1]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[1]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[1]]$collection
# [1] "emodnet-thetao_mean"
#
#
# [[2]]
# [[2]]$type
# [1] "Feature"
#
# [[2]]$stac_version
# [1] "1.0.0"
#
# [[2]]$id
# [1] "thetao_mean__depthSurf_ssp119_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00"
#
# [[2]]$properties
# [[2]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[2]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[2]]$properties$`proj:epsg`
# [1] 4326
#
# [[2]]$properties$start_datetime
# [1] "2020-01-01T00:00:00Z"
#
# [[2]]$properties$end_datetime
# [1] "2090-01-01T00:00:00Z"
#
# [[2]]$properties$native_variable
# [1] "thetao_mean"
#
# [[2]]$properties$datetime
# NULL
#
#
# [[2]]$geometry
# [[2]]$geometry$type
# [1] "Polygon"
#
# [[2]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[2]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[2]]$assets
# [[2]]$assets$NetCDF
# [[2]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_ssp119_2020_2100_depthsurf/climatologydecadedepthsurf.nc"
#
# [[2]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[2]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[2]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[2]]$assets$Zarr
# [[2]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13814/climatologydecadedepthsurf.zarr"
#
# [[2]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[2]]$assets$Zarr$title
# [1] "Zarr"
#
# [[2]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[2]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[2]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[2]]$collection
# [1] "emodnet-thetao_mean"
#
#
# [[3]]
# [[3]]$type
# [1] "Feature"
#
# [[3]]$stac_version
# [1] "1.0.0"
#
# [[3]]$id
# [1] "thetao_mean__depthSurf_ssp126_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00"
#
# [[3]]$properties
# [[3]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[3]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[3]]$properties$`proj:epsg`
# [1] 4326
#
# [[3]]$properties$start_datetime
# [1] "2020-01-01T00:00:00Z"
#
# [[3]]$properties$end_datetime
# [1] "2090-01-01T00:00:00Z"
#
# [[3]]$properties$native_variable
# [1] "thetao_mean"
#
# [[3]]$properties$datetime
# NULL
#
#
# [[3]]$geometry
# [[3]]$geometry$type
# [1] "Polygon"
#
# [[3]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[3]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[3]]$assets
# [[3]]$assets$NetCDF
# [[3]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_ssp126_2020_2100_depthsurf/climatologydecadedepthsurf.nc"
#
# [[3]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[3]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[3]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[3]]$assets$Zarr
# [[3]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13815/climatologydecadedepthsurf.zarr"
#
# [[3]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[3]]$assets$Zarr$title
# [1] "Zarr"
#
# [[3]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[3]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[3]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[3]]$collection
# [1] "emodnet-thetao_mean"
#
#
# [[4]]
# [[4]]$type
# [1] "Feature"
#
# [[4]]$stac_version
# [1] "1.0.0"
#
# [[4]]$id
# [1] "thetao_mean__depthSurf_ssp245_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00"
#
# [[4]]$properties
# [[4]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[4]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[4]]$properties$`proj:epsg`
# [1] 4326
#
# [[4]]$properties$start_datetime
# [1] "2020-01-01T00:00:00Z"
#
# [[4]]$properties$end_datetime
# [1] "2090-01-01T00:00:00Z"
#
# [[4]]$properties$native_variable
# [1] "thetao_mean"
#
# [[4]]$properties$datetime
# NULL
#
#
# [[4]]$geometry
# [[4]]$geometry$type
# [1] "Polygon"
#
# [[4]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[4]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[4]]$assets
# [[4]]$assets$NetCDF
# [[4]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_ssp245_2020_2100_depthsurf/climatologyDecadeDepthSurf.nc"
#
# [[4]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[4]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[4]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[4]]$assets$Zarr
# [[4]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13816/climatologyDecadeDepthSurf.zarr"
#
# [[4]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[4]]$assets$Zarr$title
# [1] "Zarr"
#
# [[4]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[4]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[4]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[4]]$collection
# [1] "emodnet-thetao_mean"
#
#
# [[5]]
# [[5]]$type
# [1] "Feature"
#
# [[5]]$stac_version
# [1] "1.0.0"
#
# [[5]]$id
# [1] "thetao_mean__depthSurf_ssp370_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00"
#
# [[5]]$properties
# [[5]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[5]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[5]]$properties$`proj:epsg`
# [1] 4326
#
# [[5]]$properties$start_datetime
# [1] "2020-01-01T00:00:00Z"
#
# [[5]]$properties$end_datetime
# [1] "2090-01-01T00:00:00Z"
#
# [[5]]$properties$native_variable
# [1] "thetao_mean"
#
# [[5]]$properties$datetime
# NULL
#
#
# [[5]]$geometry
# [[5]]$geometry$type
# [1] "Polygon"
#
# [[5]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[5]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[5]]$assets
# [[5]]$assets$NetCDF
# [[5]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_ssp370_2020_2100_depthsurf/climatologydecadedepthsurf.nc"
#
# [[5]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[5]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[5]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[5]]$assets$Zarr
# [[5]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13817/climatologydecadedepthsurf.zarr"
#
# [[5]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[5]]$assets$Zarr$title
# [1] "Zarr"
#
# [[5]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[5]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[5]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[5]]$collection
# [1] "emodnet-thetao_mean"
#
#
# [[6]]
# [[6]]$type
# [1] "Feature"
#
# [[6]]$stac_version
# [1] "1.0.0"
#
# [[6]]$id
# [1] "thetao_mean__depthSurf_ssp460_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00"
#
# [[6]]$properties
# [[6]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[6]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[6]]$properties$`proj:epsg`
# [1] 4326
#
# [[6]]$properties$start_datetime
# [1] "2020-01-01T00:00:00Z"
#
# [[6]]$properties$end_datetime
# [1] "2090-01-01T00:00:00Z"
#
# [[6]]$properties$native_variable
# [1] "thetao_mean"
#
# [[6]]$properties$datetime
# NULL
#
#
# [[6]]$geometry
# [[6]]$geometry$type
# [1] "Polygon"
#
# [[6]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[6]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[6]]$assets
# [[6]]$assets$NetCDF
# [[6]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_ssp460_2020_2100_depthsurf/climatologydecadedepthsurf.nc"
#
# [[6]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[6]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[6]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[6]]$assets$Zarr
# [[6]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13818/climatologydecadedepthsurf.zarr"
#
# [[6]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[6]]$assets$Zarr$title
# [1] "Zarr"
#
# [[6]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[6]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[6]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[6]]$collection
# [1] "emodnet-thetao_mean"
#
#
# [[7]]
# [[7]]$type
# [1] "Feature"
#
# [[7]]$stac_version
# [1] "1.0.0"
#
# [[7]]$id
# [1] "thetao_mean__depthSurf_ssp585_-179.975_-89.975_179.975_89.975_2020-01-01 00:00:00+00:00_2090-01-01 00:00:00+00:00"
#
# [[7]]$properties
# [[7]]$properties$provider
#         name             role
# 1 Bio-Oracle resourceProvider
#
# [[7]]$properties$`data rights and restrictions`
# [1] "CC-BY-4.0"
#
# [[7]]$properties$`proj:epsg`
# [1] 4326
#
# [[7]]$properties$start_datetime
# [1] "2020-01-01T00:00:00Z"
#
# [[7]]$properties$end_datetime
# [1] "2090-01-01T00:00:00Z"
#
# [[7]]$properties$native_variable
# [1] "thetao_mean"
#
# [[7]]$properties$datetime
# NULL
#
#
# [[7]]$geometry
# [[7]]$geometry$type
# [1] "Polygon"
#
# [[7]]$geometry$coordinates
# , , 1
#
#          [,1]     [,2]    [,3]    [,4]     [,5]
# [1,] -179.975 -179.975 179.975 179.975 -179.975
#
# , , 2
#
#         [,1]   [,2]   [,3]    [,4]    [,5]
# [1,] -89.975 89.975 89.975 -89.975 -89.975
#
#
#
# [[7]]$links
#          rel                  href             type       title
# 1       root ../../../catalog.json application/json  Bio-Oracle
# 2 collection    ../collection.json application/json thetao_mean
# 3     parent    ../collection.json application/json thetao_mean
#
# [[7]]$assets
# [[7]]$assets$NetCDF
# [[7]]$assets$NetCDF$href
# [1] "https://erddap.bio-oracle.org/erddap/files/thetao_ssp585_2020_2100_depthsurf/climatologydecadedepthsurf.nc"
#
# [[7]]$assets$NetCDF$type
# [1] "application/vnd+netcdf"
#
# [[7]]$assets$NetCDF$title
# [1] "NetCDF"
#
# [[7]]$assets$NetCDF$roles
# [1] "data"
#
#
# [[7]]$assets$Zarr
# [[7]]$assets$Zarr$href
# [1] "https://s3.waw3-1.cloudferro.com/emodnet/bio_oracle/13819/climatologydecadedepthsurf.zarr"
#
# [[7]]$assets$Zarr$type
# [1] "application/vnd+zarr"
#
# [[7]]$assets$Zarr$title
# [1] "Zarr"
#
# [[7]]$assets$Zarr$roles
# [1] "data"
#
#
#
# [[7]]$bbox
# [1] -179.975  -89.975  179.975   89.975
#
# [[7]]$stac_extensions
# [1] "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#
# [[7]]$collection
# [1] "emodnet-thetao_mean"
